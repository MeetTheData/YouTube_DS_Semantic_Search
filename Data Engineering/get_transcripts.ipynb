# %%
# !pip install youtube-transcript-api
# Out:
# Collecting youtube-transcript-api
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from youtube-transcript-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->youtube-transcript-api) (2024.8.30)
# Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Installing collected packages: youtube-transcript-api
# Successfully installed youtube-transcript-api-0.6.2

# %% [markdown]
# IMPORTS

# %%
import os
import polars as pl
from youtube_transcript_api import YouTubeTranscriptApi

# %% [markdown]
# SETTING PATH

# %%
# Change working directory to your specific folder
os.chdir('/content/drive/MyDrive/YouTube_Semantic_Search_ML/Data Engineering')

# %% [markdown]
# FUNCTIONS

# %%
def extract_text(transcript: list) -> str:
    """
        Function to extract text from transcript dictionary
    """

    text_list = [transcript[i]['text'] for i in range(len(transcript))]
    return ' '.join(text_list)

# %% [markdown]
# GET TRANSCRIPTS

# %%
# load data
df = pl.read_parquet('data/video-ids.parquet')
print(df.head())
# Out:
# shape: (5, 4)
# ┌─────────────┬──────────────────────┬──────────────────────────────┬──────────────────────────────┐
# │ video_id    ┆ datetime             ┆ title                        ┆ description                  │
# │ ---         ┆ ---                  ┆ ---                          ┆ ---                          │
# │ str         ┆ str                  ┆ str                          ┆ str                          │
# ╞═════════════╪══════════════════════╪══════════════════════════════╪══════════════════════════════╡
# │ 7Oy2NmPwJXo ┆ 2024-09-26T23:24:35Z ┆ I Quit My Job… Here’s How    ┆ Here, I share all 9 ways I   │
# │             ┆                      ┆ Much…                        ┆ scr…                         │
# │ ZVVkdXHqEuM ┆ 2024-09-23T15:45:12Z ┆ Knowledge Distillation       ┆                              │
# │             ┆                      ┆ Explain…                     ┆                              │
# │ reXoKNC_Wx4 ┆ 2024-09-20T18:15:44Z ┆ Quantization Explained in 60 ┆                              │
# │             ┆                      ┆ S…                           ┆                              │
# │ 9joIFeKuf04 ┆ 2024-09-16T14:01:44Z ┆ Python Explained in 60       ┆                              │
# │             ┆                      ┆ Seconds…                     ┆                              │
# │ pNg2DJ4spXg ┆ 2024-09-12T16:36:12Z ┆ Python QuickStart for People ┆ Here, I share a beginner     │
# │             ┆                      ┆ L…                           ┆ Quick…                       │
# └─────────────┴──────────────────────┴──────────────────────────────┴──────────────────────────────┘

# %%
# %%time
transcript_text_list = []

for i in range(len(df)):

    # try to extract captions
    try:
        transcript = YouTubeTranscriptApi.get_transcript(df['video_id'][i])
        transcript_text = extract_text(transcript)
    # if not available set as n/a
    except:
        transcript_text = "n/a"

    transcript_text_list.append(transcript_text)
# Out:
# CPU times: user 4.26 s, sys: 363 ms, total: 4.62 s
# Wall time: 1min 28s

# %%
# add transcripts to dataframe
df = df.with_columns(pl.Series(name="transcript", values=transcript_text_list))
print(df.head())
# Out:
# shape: (5, 5)
# ┌─────────────┬─────────────────────┬────────────────────┬────────────────────┬────────────────────┐
# │ video_id    ┆ datetime            ┆ title              ┆ description        ┆ transcript         │
# │ ---         ┆ ---                 ┆ ---                ┆ ---                ┆ ---                │
# │ str         ┆ str                 ┆ str                ┆ str                ┆ str                │
# ╞═════════════╪═════════════════════╪════════════════════╪════════════════════╪════════════════════╡
# │ 7Oy2NmPwJXo ┆ 2024-09-26T23:24:35 ┆ I Quit My Job…     ┆ Here, I share all  ┆ 14 months ago I    │
# │             ┆ Z                   ┆ Here’s How Much…   ┆ 9 ways I scr…      ┆ made a big lif…    │
# │ ZVVkdXHqEuM ┆ 2024-09-23T15:45:12 ┆ Knowledge          ┆                    ┆ knowledge          │
# │             ┆ Z                   ┆ Distillation       ┆                    ┆ distillation       │
# │             ┆                     ┆ Explain…           ┆                    ┆ explain…           │
# │ reXoKNC_Wx4 ┆ 2024-09-20T18:15:44 ┆ Quantization       ┆                    ┆ here's             │
# │             ┆ Z                   ┆ Explained in 60 S… ┆                    ┆ quantization       │
# │             ┆                     ┆                    ┆                    ┆ explained …        │
# │ 9joIFeKuf04 ┆ 2024-09-16T14:01:44 ┆ Python Explained   ┆                    ┆ here's python      │
# │             ┆ Z                   ┆ in 60 Seconds…     ┆                    ┆ explained in 60 …  │
# │ pNg2DJ4spXg ┆ 2024-09-12T16:36:12 ┆ Python QuickStart  ┆ Here, I share a    ┆ python is the      │
# │             ┆ Z                   ┆ for People L…      ┆ beginner Quick…    ┆ go-to programmin…  │
# └─────────────┴─────────────────────┴────────────────────┴────────────────────┴────────────────────┘

# %% [markdown]
# WRITE DATA TO FILE

# %%
# write data to file
df.write_parquet('data/video-transcripts.parquet')
df.write_csv('data/video-transcripts.csv')
